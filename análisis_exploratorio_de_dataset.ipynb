# %% [markdown]
# ##  Análisis Exploratorio del Dataset: Salud Mental y Redes Sociales
#
# Este análisis usa el dataset **Mental_Health_and_Social_Media_Balance** de Kaggle.
# Aquí se estudian hábitos de pantalla, estrés, felicidad, sueño y uso de redes sociales.
#
# Se realizan:
# - Limpieza de datos
# - Estadísticas generales
# - Filtros
# - Columnas nuevas
# - Análisis por categorías
# - 5 insights importantes

# %%
import pandas as pd

df = pd.read_csv("Mental_Health_and_Social_Media_Balance_Dataset.csv")
df.head()
# Out:
#   User_ID  Age  Gender  Daily_Screen_Time(hrs)  Sleep_Quality(1-10)  \
# 0    U001   44    Male                     3.1                  7.0
# 1    U002   30   Other                     5.1                  7.0
# 2    U003   23   Other                     7.4                  6.0
# 3    U004   36  Female                     5.7                  7.0
# 4    U005   34  Female                     7.0                  4.0
#
#    Stress_Level(1-10)  Days_Without_Social_Media  Exercise_Frequency(week)  \
# 0                 6.0                        2.0                       5.0
# 1                 8.0                        5.0                       3.0
# 2                 7.0                        1.0                       3.0
# 3                 8.0                        1.0                       1.0
# 4                 7.0                        5.0                       1.0
#
#   Social_Media_Platform  Happiness_Index(1-10)
# 0              Facebook                   10.0
# 1              LinkedIn                   10.0
# 2               YouTube                    6.0
# 3                TikTok                    8.0
# 4           X (Twitter)                    8.0

# %% [markdown]
# ### Información general del dataset:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   User_ID                    500 non-null    object
#  1   Age                        500 non-null    int64
#  2   Gender                     500 non-null    object
#  3   Daily_Screen_Time(hrs)     500 non-null    float64
#  4   Sleep_Quality(1-10)        500 non-null    float64
#  5   Stress_Level(1-10)         500 non-null    float64
#  6   Days_Without_Social_Media  500 non-null    float64
#  7   Exercise_Frequency(week)   500 non-null    float64
#  8   Social_Media_Platform      500 non-null    object
#  9   Happiness_Index(1-10)      500 non-null    float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 39.2+ KB

# %% [markdown]
# ### Estadísticas principales:

# %%
df.describe()
# Out:
#               Age  Daily_Screen_Time(hrs)  Sleep_Quality(1-10)  \
# count  500.000000              500.000000           500.000000
# mean    32.988000                5.530000             6.304000
# std      9.960637                1.734877             1.529792
# min     16.000000                1.000000             2.000000
# 25%     24.000000                4.300000             5.000000
# 50%     34.000000                5.600000             6.000000
# 75%     41.000000                6.700000             7.000000
# max     49.000000               10.800000            10.000000
#
#        Stress_Level(1-10)  Days_Without_Social_Media  \
# count          500.000000                 500.000000
# mean             6.618000                   3.134000
# std              1.542996                   1.858751
# min              2.000000                   0.000000
# 25%              6.000000                   2.000000
# 50%              7.000000                   3.000000
# 75%              8.000000                   5.000000
# max             10.000000                   9.000000
#
#        Exercise_Frequency(week)  Happiness_Index(1-10)
# count                500.000000             500.000000
# mean                   2.448000               8.376000
# std                    1.428067               1.524228
# min                    0.000000               4.000000
# 25%                    1.000000               7.000000
# 50%                    2.000000               9.000000
# 75%                    3.000000              10.000000
# max                    7.000000              10.000000

# %%
df.shape
# Out:
# (500, 10)

# %%
df.isnull().sum()
# Out:
# User_ID                      0
# Age                          0
# Gender                       0
# Daily_Screen_Time(hrs)       0
# Sleep_Quality(1-10)          0
# Stress_Level(1-10)           0
# Days_Without_Social_Media    0
# Exercise_Frequency(week)     0
# Social_Media_Platform        0
# Happiness_Index(1-10)        0
# dtype: int64

# %% [markdown]
# No se encontraron valores nulos en el dataset.

# %% [markdown]
# ## Columnas nuevas

# %% [markdown]
# ### Columna 1: Clasificación de estrés

# %%
def clasificar_estres(x):
    if x <= 3:
        return "bajo"
    elif x <= 6:
        return "moderado"
    else:
        return "alto"

df["Nivel_Estres"] = df["Stress_Level(1-10)"].apply(clasificar_estres)
df.head()
# Out:
#   User_ID  Age  Gender  Daily_Screen_Time(hrs)  Sleep_Quality(1-10)  \
# 0    U001   44    Male                     3.1                  7.0
# 1    U002   30   Other                     5.1                  7.0
# 2    U003   23   Other                     7.4                  6.0
# 3    U004   36  Female                     5.7                  7.0
# 4    U005   34  Female                     7.0                  4.0
#
#    Stress_Level(1-10)  Days_Without_Social_Media  Exercise_Frequency(week)  \
# 0                 6.0                        2.0                       5.0
# 1                 8.0                        5.0                       3.0
# 2                 7.0                        1.0                       3.0
# 3                 8.0                        1.0                       1.0
# 4                 7.0                        5.0                       1.0
#
#   Social_Media_Platform  Happiness_Index(1-10) Screen_Time_Category  \
# 0              Facebook                   10.0                Medio
# 1              LinkedIn                   10.0                Medio
# 2               YouTube                    6.0                 Alto
# 3                TikTok                    8.0                Medio
# 4           X (Twitter)                    8.0                 Alto
#
#    Emotional_Score Nivel_Estres
# 0              4.0     moderado
# 1              2.0         alto
# 2             -1.0         alto
# 3              0.0         alto
# 4              1.0         alto

# %% [markdown]
# ### Columna 2: Clasificación de sueño

# %%
def clasificar_sueno(x):
    if x <= 4:
        return "malo"
    elif x <= 7:
        return "regular"
    else:
        return "bueno"

df["Calidad_Sueno"] = df["Sleep_Quality(1-10)"].apply(clasificar_sueno)
df.head()
# Out:
#   User_ID  Age  Gender  Daily_Screen_Time(hrs)  Sleep_Quality(1-10)  \
# 0    U001   44    Male                     3.1                  7.0
# 1    U002   30   Other                     5.1                  7.0
# 2    U003   23   Other                     7.4                  6.0
# 3    U004   36  Female                     5.7                  7.0
# 4    U005   34  Female                     7.0                  4.0
#
#    Stress_Level(1-10)  Days_Without_Social_Media  Exercise_Frequency(week)  \
# 0                 6.0                        2.0                       5.0
# 1                 8.0                        5.0                       3.0
# 2                 7.0                        1.0                       3.0
# 3                 8.0                        1.0                       1.0
# 4                 7.0                        5.0                       1.0
#
#   Social_Media_Platform  Happiness_Index(1-10) Screen_Time_Category  \
# 0              Facebook                   10.0                Medio
# 1              LinkedIn                   10.0                Medio
# 2               YouTube                    6.0                 Alto
# 3                TikTok                    8.0                Medio
# 4           X (Twitter)                    8.0                 Alto
#
#    Emotional_Score Nivel_Estres Calidad_Sueno
# 0              4.0     moderado       regular
# 1              2.0         alto       regular
# 2             -1.0         alto       regular
# 3              0.0         alto       regular
# 4              1.0         alto          malo

# %% [markdown]
# ### Aplicación 3 filtros

# %%
# 1. Personas con más de 6 horas de pantalla
filtro1 = df[df["Daily_Screen_Time(hrs)"] > 6]

# 2. Personas que duermen muy bien (8+ calidad)
filtro2 = df[df["Sleep_Quality(1-10)"] >= 8]

# 3. Usuarios que NO usaron redes por más de 5 días
filtro3 = df[df["Days_Without_Social_Media"] > 5]

filtro1.head(), filtro2.head(), filtro3.head()
# Out:
# (  User_ID  Age  Gender  Daily_Screen_Time(hrs)  Sleep_Quality(1-10)  \
#  2    U003   23   Other                     7.4                  6.0
#  4    U005   34  Female                     7.0                  4.0
#  5    U006   38    Male                     6.6                  5.0
#  6    U007   26  Female                     7.8                  4.0
#  7    U008   26  Female                     7.4                  5.0
#
#     Stress_Level(1-10)  Days_Without_Social_Media  Exercise_Frequency(week)  \
#  2                 7.0                        1.0                       3.0
#  4                 7.0                        5.0                       1.0
#  5                 7.0                        4.0                       3.0
#  6                 8.0                        2.0                       0.0
#  7                 6.0                        1.0                       4.0
#
#    Social_Media_Platform  Happiness_Index(1-10) Screen_Time_Category  \
#  2               YouTube                    6.0                 Alto
#  4           X (Twitter)                    8.0                 Alto
#  5              LinkedIn                    8.0                 Alto
#  6                TikTok                    7.0                 Alto
#  7             Instagram                    7.0                 Alto
#
#     Emotional_Score
#  2             -1.0
#  4              1.0
#  5              1.0
#  6             -1.0
#  7              1.0  ,
#     User_ID  Age  Gender  Daily_Screen_Time(hrs)  Sleep_Quality(1-10)  \
#  20    U021   40  Female                     3.0                  8.0
#  22    U023   43    Male                     3.6                  8.0
#  27    U028   36  Female                     2.0                  8.0
#  32    U033   29  Female                     3.1                  8.0
#  34    U035   41   Other                     6.8                  8.0
#
#      Stress_Level(1-10)  Days_Without_Social_Media  Exercise_Frequency(week)  \
#  20                 5.0                        5.0                       4.0
#  22                 5.0                        3.0                       1.0
#  27                 4.0                        5.0                       0.0
#  32                 4.0                        2.0                       2.0
#  34                 7.0                        2.0                       2.0
#
#     Social_Media_Platform  Happiness_Index(1-10) Screen_Time_Category  \
#  20           X (Twitter)                   10.0                 Bajo
#  22              Facebook                    9.0                Medio
#  27              Facebook                   10.0                 Bajo
#  32              LinkedIn                   10.0                Medio
#  34              LinkedIn                    9.0                 Alto
#
#      Emotional_Score
#  20              5.0
#  22              4.0
#  27              6.0
#  32              6.0
#  34              2.0  ,
#     User_ID  Age  Gender  Daily_Screen_Time(hrs)  Sleep_Quality(1-10)  \
#  8     U009   39    Male                     4.7                  7.0
#  12    U013   17  Female                     7.0                  7.0
#  47    U048   33  Female                     4.1                  8.0
#  53    U054   30  Female                     6.7                  6.0
#  54    U055   23  Female                     5.2                  6.0
#
#      Stress_Level(1-10)  Days_Without_Social_Media  Exercise_Frequency(week)  \
#  8                  7.0                        6.0                       1.0
#  12                10.0                        7.0                       1.0
#  47                 7.0                        6.0                       3.0
#  53                 8.0                        6.0                       2.0
#  54                 6.0                        7.0                       3.0
#
#     Social_Media_Platform  Happiness_Index(1-10) Screen_Time_Category  \
#  8                YouTube                    9.0                Medio
#  12               YouTube                    8.0                 Alto
#  47              LinkedIn                    9.0                Medio
#  53                TikTok                    7.0                 Alto
#  54               YouTube                    8.0                Medio
#
#      Emotional_Score
#  8               2.0
#  12             -2.0
#  47              2.0
#  53             -1.0
#  54              2.0  )

# %% [markdown]
# ### GroupBy por plataformas

# %%
promedios_por_red = df.groupby("Social_Media_Platform")[
    ["Daily_Screen_Time(hrs)", "Stress_Level(1-10)", "Happiness_Index(1-10)"]
].mean()

promedios_por_red
# Out:
#                        Daily_Screen_Time(hrs)  Stress_Level(1-10)  \
# Social_Media_Platform
# Facebook                             5.658025            6.666667
# Instagram                            6.079730            6.959459
# LinkedIn                             5.291954            6.459770
# TikTok                               5.457895            6.589474
# X (Twitter)                          5.306818            6.454545
# YouTube                              5.478667            6.640000
#
#                        Happiness_Index(1-10)
# Social_Media_Platform
# Facebook                            8.345679
# Instagram                           7.986486
# LinkedIn                            8.517241
# TikTok                              8.378947
# X (Twitter)                         8.647727
# YouTube                             8.306667

# %% [markdown]
# ## Insights del Análisis
#
# Las personas que usan más horas de pantalla suelen tener más estrés.
#
# Elemento de la lista.
#
# Cuando el estrés sube, el Emotional_Score baja, lo que muestra menos bienestar.
#
# La categoría de Screen Time Alto aparece más en personas con peor calidad de sueño.
#
# Algunas redes sociales tienen usuarios con más horas de pantalla y más estrés promedio.
#
# Las personas con mejor sueño suelen tener puntajes emocionales más altos.

# %% [markdown]
# ## Conclusión
#
# En este análisis se pudo observar que las horas de pantalla, el estrés, el sueño y la felicidad están muy relacionados. Las personas que pasan más tiempo usando redes sociales tienden a tener más estrés y un puntaje emocional más bajo. También se vio que quienes duermen mejor y se alejan un poco de las redes suelen sentirse más felices. En general, el dataset muestra que mantener un mejor equilibrio entre el uso del celular, el descanso y las actividades diarias puede ayudar a mejorar el bienestar emocional.
